# %%
import sklearn

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
print(sklearn.__version__)
# Out:
# 1.0.2

# %%
print(np.__version__)
# Out:
# 1.22.2

# %%
print(pd.__version__)
# Out:
# 1.4.1

# %%
wlan_df = pd.read_csv('IOTwireless.csv')

# %%
wlan_df.head(10)
# Out:
#    version  Pad  Len  Rate ChannelFrequency  ChannelFlags  dBm_AntSignal  \
# 0        0   18  1.0  2422         CCK+2GHz           -21              1
# 0        0   18  1.0  2422         CCK+2GHz           -33              1
# 0        0   18  1.0  2422         CCK+2GHz           -21              1
# 0        0   18  1.0  2422         CCK+2GHz           -21              1
# 0        0   18  1.0  2422         CCK+2GHz           -21              1
# 0        0   18  1.0  2422         CCK+2GHz           -21              1
# 0        0   18  1.0  2422         CCK+2GHz           -21              1
# 0        0   18  1.0  2422         CCK+2GHz           -21              1
# 0        0   18  1.0  2422         CCK+2GHz           -27              1
# 0        0   18  1.0  2422         CCK+2GHz           -21              1
#
#    Antenna  subtype  type  ... FCfield                 ID              addr1  \
# 0        8        0     0  ...       0  ff:ff:ff:ff:ff:ff  24:f5:a2:72:d2:e4
# ...
